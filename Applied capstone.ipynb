# %% [markdown]
# <H1><font colour=blue>THIS NOTEBOOK WOULD BE USED FOR THE APPLIED DATA CAPSTONE ASSIGNMENT</font>

# %%
#import pandas library
import pandas as pd

# %%
#import numpy library
import numpy as np

# %%
text = "Hello Capstone Project Course"
print (text)
# Out:
# Hello Capstone Project Course
